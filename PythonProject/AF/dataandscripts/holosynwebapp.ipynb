# %%
# !apt-get update -y >/dev/null 2>&1 || true
# !apt-get update -y
# !apt-get install -y ffmpeg

# unzip into /content/holosyn_webapp
# !rm -rf /content/holosyn_webapp
# !unzip -o /content/holosyn_webapp.zip -d /content/holosyn_webapp

# %cd /content/holosyn_webapp

# !pip -q install -r holosyn_webapp/requirements.txt
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
import os, re, pathlib

app_path = pathlib.Path("holosyn_webapp/app.py")
txt = app_path.read_text()

# If your app doesn't already set share=True, patch it safely.
# This tries to modify demo.launch(...) to include share=True.
patched = re.sub(
    r"(\.launch\()\s*",
    r"\1share=True, ",
    txt
)

if patched == txt:
    print("Could not auto-patch launch(). If you don't get a public link, I’ll show a manual fix below.")
else:
    app_path.write_text(patched)
    print("Patched app.py to launch with share=True")
# Out:
# Patched app.py to launch with share=True
